# %% [markdown]
# Why we need missing value in datascience?
# Avoid errors in algorithms
#
# Improve model accuracy
#
# Prevent biased results
#
# Ensure correct statistical analysis
#
# Preserve useful data
#
# Improve data quality and consistency
#
# Support machine learning models
#
# Handle real-world incomplete data
#
# Enable reliable predictions
#
# Improve decision-making

# %%
import pandas as pd
import numpy as np

# Sample dataset
data = {
    'Age': [25, np.nan, 30, 28, np.nan],
    'Salary': [50000, 60000, np.nan, 52000, 58000],
    'Department': ['IT', 'HR', np.nan, 'IT', 'IT']
}

df = pd.DataFrame(data)
df
# Out:
#     Age   Salary Department
# 0  25.0  50000.0         IT
# 1   NaN  60000.0         HR
# 2  30.0      NaN        NaN
# 3  28.0  52000.0         IT
# 4   NaN  58000.0         IT

# %%
#Listwise Deletion(Row Deletion)
df_listwise = df.dropna()
df_listwise
# Out:
#     Age   Salary Department
# 0  25.0  50000.0         IT
# 3  28.0  52000.0         IT

# %%
#Mean Imputation
df_mean = df.copy()
df_mean['Age'].fillna(df_mean['Age'].mean(), inplace=True)
df_mean['Salary'].fillna(df_mean['Salary'].mean(), inplace=True)
df_mean
# Out:
# /tmp/ipython-input-3573604130.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mean['Age'].fillna(df_mean['Age'].mean(), inplace=True)
# /tmp/ipython-input-3573604130.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
#Median Imputation
df_median = df.copy()
df_median['Age'].fillna(df_median['Age'].median(), inplace=True)
df_median['Salary'].fillna(df_median['Salary'].median(), inplace=True)
df_median
# Out:
# /tmp/ipython-input-3194608356.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_median['Age'].fillna(df_median['Age'].median(), inplace=True)
# /tmp/ipython-input-3194608356.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
#Constant Value Imputation
df_constant = df.copy()
df_constant.fillna({'Age': 0, 'Salary': 0, 'Department': 'Unknown'}, inplace=True)
df_constant
# Out:
#     Age   Salary Department
# 0  25.0  50000.0         IT
# 1   0.0  60000.0         HR
# 2  30.0      0.0    Unknown
# 3  28.0  52000.0         IT
# 4   0.0  58000.0         HR

# %%
# Mode Imputation (Categorical)
df_mode = df.copy()
df_mode['Department'].fillna(df_mode['Department'].mode()[0], inplace=True)
df_mode
# Out:
# /tmp/ipython-input-3999603434.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mode['Department'].fillna(df_mode['Department'].mode()[0], inplace=True)
#     Age   Salary Department
# 0  25.0  50000.0         IT
# 1   NaN  60000.0         HR
# 2  30.0      NaN         IT
# 3  28.0  52000.0         IT
# 4   NaN  58000.0         IT

# %%
#Advanced Stastical Imputation
#1.Regression
#2.K-nn imputation
