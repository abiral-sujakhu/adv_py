# %%
import pandas as pd

# Sample categorical data with missing values
data = {
    'Category': ['Red', None, 'Blue', 'Green', None, 'Blue', None]
}
df = pd.DataFrame(data)
print("Original Data:")
df
# Out:
# Original Data:
#   Category
# 0      Red
# 1     None
# 2     Blue
# 3    Green
# 4     None
# 5     Blue
# 6     None

# %%
# 1. Mode Imputation (replace missing with most frequent category)
df_mode = df.copy()
df_mode['Category'].fillna(df_mode['Category'].mode()[0], inplace=True)
print("\nAfter Mode Imputation:")
df_mode
# Out:
# After Mode Imputation:
# C:\Users\mausa\AppData\Local\Temp\ipykernel_25916\3400149311.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_mode['Category'].fillna(df_mode['Category'].mode()[0], inplace=True)
#   Category
# 0      Red
# 1     Blue
# 2     Blue
# 3    Green
# 4     Blue
# 5     Blue
# 6     Blue

# %%
# 2. Constant Value Imputation (replace missing with 'Unknown')
df_constant = df.copy()
df_constant['Category'].fillna('Unknown', inplace=True)
print("\nAfter Constant Value Imputation:")
df_constant
# Out:
# After Constant Value Imputation:
# C:\Users\mausa\AppData\Local\Temp\ipykernel_25916\927773345.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_constant['Category'].fillna('Unknown', inplace=True)
#   Category
# 0      Red
# 1  Unknown
# 2     Blue
# 3    Green
# 4  Unknown
# 5     Blue
# 6  Unknown

# %%
# 3. Forward Fill / Backward Fill (propagate last known value)
df_ffill = df.copy()
df_ffill['Category'].fillna(method='ffill', inplace=True)
print("\nAfter Forward Fill:")
df_ffill
# Out:
# After Forward Fill:
# C:\Users\mausa\AppData\Local\Temp\ipykernel_25916\3312433887.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ffill['Category'].fillna(method='ffill', inplace=True)
# C:\Users\mausa\AppData\Local\Temp\ipykernel_25916\3312433887.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill['Category'].fillna(method='ffill', inplace=True)
#   Category
# 0      Red
# 1      Red
# 2     Blue
# 3    Green
# 4    Green
# 5     Blue
# 6     Blue

# %%
# Backward Fill (propagate next known value)
df_bfill = df.copy()
df_bfill['Category'].fillna(method='bfill', inplace=True)
print("\nAfter Backward Fill:")
df_bfill
# Out:
# After Backward Fill:
# C:\Users\mausa\AppData\Local\Temp\ipykernel_25916\3202688532.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_bfill['Category'].fillna(method='bfill', inplace=True)
# C:\Users\mausa\AppData\Local\Temp\ipykernel_25916\3202688532.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill['Category'].fillna(method='bfill', inplace=True)
#   Category
# 0      Red
# 1     Blue
# 2     Blue
# 3    Green
# 4     Blue
# 5     Blue
# 6     None
